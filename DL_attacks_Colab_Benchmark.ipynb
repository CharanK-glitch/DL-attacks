# %% [markdown]
# # 🚀 DL-Attacks: Adversarial ML Benchmark on Google GPU
# This notebook runs FGSM and PGD adversarial attacks on Google Colab GPU instances.
#
# ### **Instructions:**
# 1. In Google Colab, click **Runtime -> Change runtime type** and select **T4 GPU**.
# 2. Run the cells below to clone your repository and execute the benchmark with full GPU acceleration.

# %%
# 1. Clone Repository from GitHub & Change Directory
# !git clone https://github.com/CharanK-glitch/DL-attacks.git
# %cd DL-attacks
# Out:
# Cloning into 'DL-attacks'...
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 35 (delta 3), reused 34 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (35/35), 2.80 MiB | 6.60 MiB/s, done.
# Resolving deltas: 100% (3/3), done.
# /content/DL-attacks

# %%
# 2. Verify Google GPU Connection
import torch
print('GPU Available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU Device Name:', torch.cuda.get_device_name(0))
# !nvidia-smi
# Out:
# GPU Available: True
# GPU Device Name: Tesla T4
# Sat Sep  5 20:03:09 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8             14W /   70W |       3MiB /  15360MiB |      0%      Default |
# ...

# %%
# 3. Install Required Dependencies
# !pip install torch torchvision huggingface_hub timm matplotlib

# %%
# 4. Run FGSM & PGD Adversarial Benchmark on GPU
# !python main.py
# Out:
# [*] Running Adversarial Benchmark on device: cuda (using 4 CPU threads max)
# ...
#
# pytorch_model.bin: downloading bytes:  67% 30.2M/44.8M [00:01<00:00, 43.8MB/s, 1.17MB/s  ]
# pytorch_model.bin: downloading bytes: 100% 41.2M/41.2M [00:01<00:00, 35.7MB/s, 3.99MB/s  ]
# pytorch_model.bin: reconstructing file: 100% 44.8M/44.8M [00:01<00:00, 38.8MB/s, 4.37MB/s  ]
# [+] Loaded pre-trained CIFAR-10 ResNet-18 weights (95%+ accuracy).
# [*] Loading CIFAR-10 test dataset...
#  14% 23.7M/170M [02:37<16:52, 145kB/s]

# %%
# 5. Display Result Plots
from IPython.display import Image, display
print('--- FGSM Attack Sample ---')
display(Image('./results/fgsm_sample.png'))
print('--- PGD Attack Sample ---')
display(Image('./results/pgd_sample.png'))
