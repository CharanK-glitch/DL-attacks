# %% [markdown]
# # 🚀 DL-Attacks: Adversarial ML Benchmark on Google GPU
# This notebook runs FGSM and PGD adversarial attacks on Google Colab GPU instances and displays publication-ready visualization plots.
#
# ### **Instructions:**
# 1. In Google Colab, click **Runtime -> Change runtime type** and select **T4 GPU**.
# 2. Run the cells below to clone your repository, execute the benchmark on GPU, and display all 5 visual result plots.

# %%
# 1. Clone Repository from GitHub & Change Directory
# !git clone https://github.com/CharanK-glitch/DL-attacks.git
# %cd DL-attacks

# %%
# 2. Verify Google GPU Connection
import torch
print('GPU Available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU Device Name:', torch.cuda.get_device_name(0))
# !nvidia-smi

# %%
# 3. Install Required Dependencies
# !pip install torch torchvision huggingface_hub timm matplotlib

# %%
# 4. Run FGSM & PGD Adversarial Benchmark on GPU
# !python main.py

# %%
# 5. Display All 5 Result Plots
from IPython.display import Image, display

print('📊 --- 1. Accuracy vs Epsilon Robustness Curve ---')
display(Image('./results/accuracy_vs_epsilon.png'))

print('🖼️ --- 2. Multi-Sample Adversarial Grid ---')
display(Image('./results/adversarial_grid.png'))

print('📊 --- 3. Class Confidence Probability Distribution ---')
display(Image('./results/confidence_bar.png'))

print('🖼️ --- 4. FGSM Attack Sample ---')
display(Image('./results/fgsm_sample.png'))

print('🖼️ --- 5. PGD Attack Sample ---')
display(Image('./results/pgd_sample.png'))
